# %%
import gribberish
import xarray as xr

ds = xr.open_dataset('box_nwps_CG1_20230706_1800.grib2', engine='gribberish')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 145, latitude: 156, longitude: 155)
# Coordinates:
#   * time       (time) datetime64[ns] 2023-07-06T18:00:00 ... 2023-07-12T18:00:00
#   * latitude   (latitude) float64 40.45 40.47 40.49 40.5 ... 43.21 43.23 43.25
#   * longitude  (longitude) float64 287.5 287.5 287.5 287.6 ... 291.1 291.1 291.2
# Data variables: (12/18)
#     wind       (time, latitude, longitude) float64 ...
#     dirc       (time, latitude, longitude) float64 ...
#     dirpw      (time, latitude, longitude) float64 ...
#     erosnp     (time, latitude, longitude) float64 ...
#     twlwav     (time, latitude, longitude) float64 ...
#     perpw      (time, latitude, longitude) float64 ...
#     ...         ...
#     swash      (time, latitude, longitude) float64 ...
#     dslm       (time, latitude, longitude) float64 ...
#     spc        (time, latitude, longitude) float64 ...
#     setup      (time, latitude, longitude) float64 ...
#     twldc      (time, latitude, longitude) float64 ...
#     wdir       (time, latitude, longitude) float64 ...
# Attributes:
#     meta:     Generated with gribberishpy

# %%
ndbc_44097_latitude = 40.967
ndbc_44097_longitude = 360 - 70.167

ds.htsgw.interp(latitude=ndbc_44097_latitude, longitude=ndbc_44097_longitude, method='linear').plot()
