# %%
import gribberish
import xarray as xr
import matplotlib.pyplot as plt

ds = xr.open_dataset('box_nwps_CG1_20230706_1800.grib2', engine='gribberish', chunks={})
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 145, latitude: 156, longitude: 155)
# Coordinates:
#   * time       (time) datetime64[ns] 2023-07-06T18:00:00 ... 2023-07-12T18:00:00
#   * latitude   (latitude) float64 40.45 40.47 40.49 40.5 ... 43.21 43.23 43.25
#   * longitude  (longitude) float64 287.5 287.5 287.5 287.6 ... 291.1 291.1 291.2
# Data variables: (12/18)
#     dirc       (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     twlwav     (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     erosnp     (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     setup      (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     swell      (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     perpw      (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     ...         ...
#     dslm       (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     twldt      (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     spc        (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     owashp     (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     runup      (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
#     ripcop     (time, latitude, longitude) float64 dask.array<chunksize=(145, 156, 155), meta=np.ndarray>
# Attributes:
#     meta:     Generated with gribberishpy

# %%
ds.htsgw.isel(time=0).plot()

# %%
ndbc_44097_latitude = 40.967
ndbc_44097_longitude = 360 - 70.167

vals = ds.htsgw.interp(latitude=ndbc_44097_latitude, longitude=ndbc_44097_longitude, method='linear')
print(vals.max().values)
# Out:
# 1.040335387081826
