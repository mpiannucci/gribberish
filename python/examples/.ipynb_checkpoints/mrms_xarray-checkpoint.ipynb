# %%
import xarray as xr

# %%
ds = xr.open_dataset('MRMS_MergedReflectivityQCComposite_00.50_20220704-110040.grib2', engine='gribberish')
ds
# Out:
# <xarray.Dataset> Size: 196MB
# Dimensions:                        (time: 1, latitude: 3500, longitude: 7000)
# Coordinates:
#   * time                           (time) datetime64[s] 8B 2022-07-04T11:00:40
#   * latitude                       (latitude) float64 28kB 54.99 54.98 ... 20.0
#   * longitude                      (longitude) float64 56kB 230.0 ... 300.0
# Data variables:
#     mergedreflectivityqccomposite  (time, latitude, longitude) float64 196MB ...
# Attributes:
#     meta:     Generated with gribberishpy

# %%
ds.mergedreflectivityqccomposite.plot(vmin=0)
