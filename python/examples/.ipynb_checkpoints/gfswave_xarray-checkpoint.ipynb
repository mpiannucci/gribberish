# %%
import xarray as xr

# %%
ds = xr.open_dataset('gfswave.20210826.t12z.atlocn.0p16.f000.grib2', engine='gribberish')
ds
# Out:
# <xarray.Dataset> Size: 15MB
# Dimensions:    (time: 1, latitude: 331, longitude: 301, seq: 3)
# Coordinates:
#   * time       (time) datetime64[s] 8B 2021-08-26T12:00:00
#   * latitude   (latitude) float64 3kB 55.0 54.83 54.67 ... 0.1666 -0.00011
#   * longitude  (longitude) float64 2kB 260.0 260.2 260.3 ... 309.7 309.8 310.0
#   * seq        (seq) float64 24B 1.0 2.0 3.0
# Data variables: (12/13)
#     wdir       (time, latitude, longitude) float64 797kB ...
#     swell      (time, seq, latitude, longitude) float64 2MB ...
#     ugrd       (time, latitude, longitude) float64 797kB ...
#     dirpw      (time, latitude, longitude) float64 797kB ...
#     htsgw      (time, latitude, longitude) float64 797kB ...
#     perpw      (time, latitude, longitude) float64 797kB ...
#     ...         ...
#     wvhgt      (time, latitude, longitude) float64 797kB ...
#     swdir      (time, seq, latitude, longitude) float64 2MB ...
#     wvper      (time, latitude, longitude) float64 797kB ...
# ...

# %%
ds.wvhgt.plot()
