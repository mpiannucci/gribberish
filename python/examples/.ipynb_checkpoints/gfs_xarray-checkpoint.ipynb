# %%
import cf_xarray
import gribberish
import xarray as xr
import cfgrib

# %%
# %%time

dt = xr.open_datatree(
    '../../../../Downloads/gfs.t12z.pgrb2.0p25.f023',
    storage_options={'skip_signature': True, 'region': 'us-east-1'},
    engine='gribberish'
)
dt
# Out:
# CPU times: user 303 ms, sys: 205 ms, total: 508 ms
# Wall time: 765 ms
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       meta:     Generated with gribberishpy
# ├── Group: /avg5h
# │       Dimensions:    (time: 1, latitude: 721, longitude: 1440)
# │       Coordinates:
# │         * time       (time) datetime64[s] 8B 2026-06-06T11:00:00
# │         * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
# │         * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
# │       Data variables:
# │           tmp        (time, latitude, longitude) float64 8MB ...
# │           pres       (time, latitude, longitude) float64 8MB ...
# │       Attributes:
# │           meta:     Generated with gribberishpy
# ├── Group: /instant
# │       Dimensions:    (time: 1, latitude: 721, longitude: 1440)
# │       Coordinates:
# │         * time       (time) datetime64[s] 8B 2026-06-06T11:00:00
# ...

# %%
instant_ds = dt['sfc/instant']
instant_ds
# Out:
# <xarray.DataTree 'instant'>
# Group: /sfc/instant
#     Dimensions:    (time: 1, latitude: 721, longitude: 1440)
#     Coordinates:
#       * time       (time) datetime64[s] 8B 2026-06-06T11:00:00
#       * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#       * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     Data variables: (12/33)
#         cpofp      (time, latitude, longitude) float64 8MB ...
#         cicep      (time, latitude, longitude) float64 8MB ...
#         icetmp     (time, latitude, longitude) float64 8MB ...
#         csnow      (time, latitude, longitude) float64 8MB ...
#         land       (time, latitude, longitude) float64 8MB ...
#         pevpr      (time, latitude, longitude) float64 8MB ...
#         ...         ...
#         weasd      (time, latitude, longitude) float64 8MB ...
#         pres       (time, latitude, longitude) float64 8MB ...
# ...

# %%
instant_ds.tmp.plot()

# %%
ds = xr.open_dataset('../../../../Downloads/gfs.t12z.pgrb2.0p25.f023', engine='cfgrib', filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'surface'})
ds
# Out:
# <xarray.Dataset> Size: 133MB
# Dimensions:     (latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     time        datetime64[ns] 8B ...
#     step        timedelta64[ns] 8B ...
#     surface     float64 8B ...
#     valid_time  datetime64[ns] 8B ...
# Data variables: (12/32)
#     vis         (latitude, longitude) float32 4MB ...
#     gust        (latitude, longitude) float32 4MB ...
#     hindex      (latitude, longitude) float32 4MB ...
#     sp          (latitude, longitude) float32 4MB ...
#     orog        (latitude, longitude) float32 4MB ...
#     t           (latitude, longitude) float32 4MB ...
#     ...          ...
#     cape        (latitude, longitude) float32 4MB ...
#     cin         (latitude, longitude) float32 4MB ...
#     lftx4       (latitude, longitude) float32 4MB ...
# ...

# %%
ds.t.plot()
